# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; ">
#         <img src="./img/h-m-re.png" style="width: 100px;" alt="">
#         <p style="text-align: center; font-size: 40px; color:black;"> Exercise - 7</p>
#     </div>

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="background-color:transparent;font-family:newtimeroman;color:black;font-size:60px;text-align:center; margin-top:15px">
#         Flights
#         </p>
#         <video autoplay muted loop plays-inline style="width:800px; height:auto; border-radius:10px 10px;">
#             <source src="./video/plane_-_3966 (540p).mp4" type="video/mp4">
#         </video>
#         <p style="text-align: center; font-size: 40px; color:black; font-weight:bold"> This dataset contains information about all flights that departed from NYC (e.g. EWR, JFK and LGA) in 2013: 336,776 flights in total. The dataset misses the data related to the cause of delays.
#         </p>
#         <p style="text-align: left; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px">
#         ID : A unique identifier for each flight record in the dataset.<br>
#         YEAR : The year in which the flight took place (2013 in this dataset).<br>
#         MONTH : The month in which the flight took place (1 to 12).<br>
#         DAY : The day of the month on which the flight took place (1 to 31).<br>
#         DEP_TIME: The actual local departure time of the flight, in 24-hour format (hhmm).<br>
#         SCHED_DEP_TIME : The scheduled local departure time of the flight, in 24-hour format (hhmm).<br>
#         DEP_DELAY : The difference between the actual and scheduled departure times of the flight, in minutes. A positive value indicates a delayed departure, while a negative value indicates an early departure.<br>
#         ARR_TIME : The actual local arrival time of the flight, in 24-hour format (hhmm).<br>
#         SCHED_ARR_TIME : The scheduled local arrival time of the flight, in 24-hour format (hhmm).<br>
#         ARR_DELAY : The difference between the actual and scheduled arrival times of the flight, in minutes. A positive value indicates a delayed arrival, while a negative value indicates an early arrival.<br>
#         CARRIER : The two-letter code of the airline carrier for the flight.<br>
#         FLIGHT : The flight number of the flight.<br>
#         TAILNUM : The unique identifier of the aircraft used for the flight.<br>
#         ORIGIN : The three-letter code of the airport of origin for the flight.<br>
#         DEST : The three-letter code of the destination airport for the flight.<br>
#         AIT_TIME : The duration of the flight, in minutes.<br>
#         DISTANCE : The distance between the origin and destination airports, in miles.<br>
#         HOUR : The hour component of the scheduled departure time, in local time.<br>
#         MINUTE : The minute component of the scheduled departure time, in local time.<br>
#         TIME_HOUR : The scheduled departure time of the flight, in local time and format (yyyy-mm-dd hh:mm:ss).<br>
#         NAME : The name of the airline carrier for the flight<br>
#         </p>
#     </div>

# %% [markdown]
#  <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center;  ">
#         <img src="./img/lib-re.png" style="width: 100px; margin-top: 15px;" alt="">
#         <p style="text-align: center; font-size: 40px; color:black;"> IMPORTING LIBRARY</p>
#     </div>

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="background-color:transparent;font-family:newtimeroman;color:black;font-size:60px;text-align:center; margin-top:15px">
#         Loading Data
#         </p>
#         <video autoplay muted loop plays-inline style="width:800px; height:auto; border-radius:10px 10px; margin-bottom:15px">
#             <source src="./video/data_-_22034 (540p).mp4" type="video/mp4">
#         </video>
#
# </div>

# %%
df = pd.read_csv("./flights.csv")

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="background-color:transparent;font-family:newtimeroman;color:black;font-size:60px;text-align:center; margin-top:15px">
#         Data Over View
#         </p>
#         <video autoplay muted loop plays-inline style="width:800px; height:auto; border-radius:10px 10px; margin-bottom:15px">
#             <source src="./video/data_-_746 (360p).mp4" type="video/mp4">
#         </video>
#
# </div>

# %%
rows,cols = df.shape
print("Number of rows: ", rows)
print("Number of columns: ", cols)
# Out:
# Number of rows:  336776
# Number of columns:  21

# %%
df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id      year          month            day       dep_time  \
# count  336776.000000  336776.0  336776.000000  336776.000000  328521.000000
# mean   168387.500000    2013.0       6.548510      15.710787    1349.109947
# std     97219.001466       0.0       3.414457       8.768607     488.281791
# min         0.000000    2013.0       1.000000       1.000000       1.000000
# 25%     84193.750000    2013.0       4.000000       8.000000     907.000000
# 50%    168387.500000    2013.0       7.000000      16.000000    1401.000000
# 75%    252581.250000    2013.0      10.000000      23.000000    1744.000000
# max    336775.000000    2013.0      12.000000      31.000000    2400.000000
#
#        sched_dep_time      dep_delay       arr_time  sched_arr_time  \
# count   336776.000000  328521.000000  328063.000000   336776.000000
# mean      1344.254840      12.639070    1502.054999     1536.380220
# std        467.335756      40.210061     533.264132      497.457142
# ...

# %%
df.isnull().any()
# Out:
# id                False
# year              False
# month             False
# day               False
# dep_time           True
# sched_dep_time    False
# dep_delay          True
# arr_time           True
# sched_arr_time    False
# arr_delay          True
# carrier           False
# flight            False
# tailnum            True
# origin            False
# dest              False
# air_time           True
# distance          False
# hour              False
# minute            False
# time_hour         False
# name              False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                   0
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="background-color:transparent;font-family:newtimeroman;color:black;font-size:60px;text-align:center; margin-top:15px">
#         Data Analysis <br>
#         and<br>
#         Reporting
#         </p>
#         <video autoplay muted loop plays-inline style="width:800px; height:auto; border-radius:10px 10px; margin-bottom:15px">
#             <source src="./video/dashboard_-_10847 (540p).mp4" type="video/mp4">
#         </video>
#
# </div>

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="text-align: center; font-size: 25px; color:black; "> Chart of number of flights by month
#         </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;">
#      نمودار تعداد پروازها بر اساس ماه
#
#    </p>
#     </div>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='month')
plt.title('Number of flights by month')
plt.xlabel('Month')
plt.ylabel('Flights')
plt.show()

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="text-align: center; font-size: 25px; color:black; "> Flight arrival delay chart </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;"> نمودار تاخیر رسیدن پروازها</p>
#     </div>

# %%
arrival_delay = df['arr_delay'].dropna()

plt.figure(figsize=(10, 6))
sns.histplot(arrival_delay, kde=True)
plt.title('Attendance delay distribution')
plt.xlabel('Arrive delay(minutes)')
plt.ylabel('Abundance')
plt.show()

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="text-align: center; font-size: 25px; color:black; ">Calculate The Number Of Flights Based On Each Airlines </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;"> محاسبه تعداد پروازها بر اساس هر خط هوایی
# پروازها</p>
#     </div>

# %%
carrier_counts = df['carrier'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=carrier_counts.index, y=carrier_counts.values)
plt.title('The Number Of Flights Based On Each Airlines')
plt.xlabel('carrier')
plt.ylabel('flights')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center;  ">
#         <p style="text-align: center; font-size: 40px; color:black; margin-top:30px; font-weight:bolder; margin-right:20px;"> Reporting</p>
#         <img src="./img/1.png" style="width: 100px; margin-top: 15px;" alt="">
#
# </div>

# %%
 
# Checking flight delays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='dep_delay', y='dep_time', data=df)
plt.xlabel('Departure Delay (minutes)')
plt.ylabel('Departure')
# Out:
# Text(0, 0.5, 'Departure')

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="background-color:transparent;font-family:newtimeroman;color:black;font-size:60px;text-align:center; margin-top:15px">
#         Departure Delay
#         </p>
#         <video autoplay muted loop plays-inline style="width:800px; height:auto; border-radius:10px 10px;">
#             <source src="./video/clock_-_43008 (540p).mp4" type="video/mp4">
#         </video>
#         <p style="text-align: center; font-size: 25px; color:black; "> This chart uses the horizontal axis to show the flight delay in minutes and the vertical axis to show the flight departure time.
# Each representative point of a flight is placed on the graph, and by checking the position of the points, we can analyze the delays resulting from non-compliance with the planning time.
#   If the points move up and to the left of the chart, this indicates more delays and slower flights. In this way, it can be said that the flights located at the higher and left points have more delays than the flights located at the lower and right points.
#   This chart helps us identify flight delay patterns. By analyzing the distribution of points and the patterns that form, we can get a better understanding of the impact of delays on flight departure times and their prevalence. In this way, we can make better decisions for planning flights. And we can also take measures to improve and reduce delays.
#         </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;">
#          این نمودار با استفاده از محور افقی برای نمایش تاخیر در حرکت پروازها به واحد دقیقه و محور عمودی برای نمایش زمان حرکت پروازها  است.
# هر نقطه نماینده یک پرواز بر روی نمودار قرار گرفته‌ است  و  با بررسی موقعیت نقاط، تاخیرهای حاصل از عدم رعایت زمان برنامه‌ریزی را میتوانیم تحلیل کنیم.
#  اگر نقاط به سمت بالا و چپ نمودار جابجا بشوند، این نشانگر تاخیرهای بیشتر و حرکت پروازها دیرتر هست. اینجوری میشه گفت که ، پروازهایی که در نقاط بالاتر و سمت چپ قرار دارند، تاخیرهای بیشتری نسبت به پروازهایی که در نقاط پایین‌تر و سمت راست قرار دارند، داشتن.
#  این نمودار به ما کمک می‌کنه الگوهای تاخیر در حرکت پروازها را تشخیص بدیم. با واکاوی توزیع نقاط و الگوهایی که شکل می‌گیرن، می‌تونیم درک بهتری از تأثیر تاخیر بر زمان حرکت پروازها و شیوع آنها پیدا کنیم. از این طریق میتونیم تصمیم گیری بهتری داشته باشیم برای برنامه ریزی پروازها. و همچنین میتونیم دست به اقداماتی بزنیم که بهبود پیدا کنه تاخیرهای زیاد  و کاهش تاخیر رو داشته باشیم.
#         </p>
#     </div>

# %% [markdown]
#  <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center;  ">
#         <p style="text-align: center; font-size: 40px; color:black; margin-top:30px; font-weight:bolder; margin-right:20px;"> Reporting</p>
#         <img src="./img/2.webp" style="width: 100px; margin-top: 15px;" alt="">
#
# </div>

# %%
carrier_delays = df.groupby('carrier')['arr_delay'].mean().sort_values()

plt.bar(carrier_delays.index, carrier_delays.values)
plt.xlabel('air Lines')
plt.ylabel('Average flight delay (minutes)')
plt.title('Average flight delays by airline')
plt.xticks(rotation=45)
plt.show()

# %%
carrier_arrival_delay = df.groupby('carrier')['arr_delay'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=carrier_arrival_delay.index, y=carrier_arrival_delay.values)
plt.title('Average flight delays by airline')
plt.xlabel('airlines')
plt.ylabel('Average flight delay (minutes)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="background-color:transparent;font-family:newtimeroman;color:black;font-size:60px;text-align:center; margin-top:15px">
#         Average Flight Delays By Airline
#         </p>
#         <video autoplay muted loop plays-inline style="width:800px; height:auto; border-radius:10px 10px;">
#             <source src="./video/airport_-_10874 (540p).mp4" type="video/mp4">
#         </video>
#         <p style="text-align: center; font-size: 25px; color:black; ">
#         In this chart, we can see the average delay in flights based on airlines. This chart can help us understand and compare the average delays between different airlines. According to this chart, we can understand which airlines have higher average delays and which airlines have performed better. In this graph, the horizontal axis shows the airlines we have and the vertical axis shows the average flight delay in minutes. According to the height of the columns, we can compare the average delay of each airline.
#         </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;">
#         در این دو نمودار بالا میانگین تأخیر در پروازها بر اساس خطوط هوایی رو میتونیم ببینم.  این نمودار می‌تونه به ما در درک و مقایسه میانگین تأخیرهای مختلف بین خطوط هوایی کمک کنه. با توجه به این نمودار، می‌تونیم بفهمیم کدام خطوط هوایی دارای میانگین تأخیر بیشتری هست و کدام خطوط هوایی عملکرد بهتری داشته. دراین  نمودار، محور افقی نشون میده خطوط هوایی که داریم و محور عمودی نشون میده میانگین تأخیر در پروازها رو که به دقیقه هست. با توجه به ارتفاع ستون‌ها، میتونیم میانگین تأخیر هر خط هوایی را مقایسه کنیم.
#         </p>
#     </div>

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="text-align: center; font-size: 25px; color:black; "> This chart shows how arrival delays are distributed across different airlines and also helps us see patterns and differences in arrival delays between airlines
#         </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;">
#         این نمودار زیر نشان می‌ده که تاخیرهای ورود چگونه در خطوط هوایی مختلف توزیع می‌شن وهمچنین به ما کمک میکنه تا الگوها و تفاوت‌های تاخیر ورود را بین خطوط هوایی ببینیم.
#         </p>
#     </div>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='arr_delay', y='carrier', data=df)
plt.xlabel('Arrival Delay (minutes)')
plt.ylabel('Carrier')
plt.title('Arrival Delay Distribution by Carrier')
plt.show()

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center;  ">
#         <p style="text-align: center; font-size: 40px; color:black; margin-top:30px; font-weight:bolder; margin-right:20px;"> Reporting</p>
#         <img src="./img/3.png" style="width: 100px; margin-top: 15px;" alt="">
#
# </div>

# %%
df['dep_delay'] = df['dep_delay'].fillna(0)

carrier_delay = df.groupby('carrier')['dep_delay'].mean().sort_values(ascending=False)

sns.barplot(x=carrier_delay.index, y=carrier_delay.values)
plt.xlabel('َAirlines')
plt.ylabel('Average departure delay')
plt.title('Average departure delay by airline')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="background-color:transparent;font-family:newtimeroman;color:black;font-size:60px;text-align:center; margin-top:15px">
#         Average Departure Delay By Airline
#         </p>
#         <video autoplay muted loop plays-inline style="width:800px; height:auto; border-radius:10px 10px;">
#             <source src="./video/landing_-_10690 (540p).mp4" type="video/mp4">
#         </video>
#         <p style="text-align: center; font-size: 25px; color:black; ">
#         This chart gives us information about the amount of airline flight delays.
# This chart can be used to compare average flight delays between airlines and determine which airlines have the longest average delays.
# This chart shows a column for each airline, and the height of the column represents the average departure delay of that airline. This height indicates less and more delay.
# In this chart, you can see which airlines tend to experience more flight delays and which companies operate with less delays.
#         </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;">این نمودار اطلاعاتی در مورد میزان تاخیر پروازهای خطوط هوایی به ما می ده.
# از این نمودار میشه برای مقایسه میانگین تاخیرهای پرواز بین خطوط هوایی و تعیین اینکه کدام خطوط هوایی بیشترین میانگین تاخیر را دارند استفاده کرد.
# این نمودار یک ستون برای هر ایرلاین نشان می دهد و ارتفاع ستون نشان دهنده میانگین تاخیر خروج آن شرکت هواپیمایی است. این ارتفاع نشان دهنده تاخیر کمتر و بیشتر هست.
# در این نمودار، می‌شه دید که که کدام خطوط هوایی معمولاً تأخیر پرواز بیشتری را تجربه می‌کنند و کدام شرکت‌ها با تأخیر کمتری کار می‌کنند.
#         </p>
#     </div>

# %% [markdown]
# <div style="background-color:rgb(218, 65, 154); border-radius: 25px; display: flex; justify-content: center; align-items: center; flex-direction: column;">
#         <p style="text-align: center; font-size: 25px; color:black; "> In the diagram below, for example, to compare the average delay in movement between two or more airlines, we can have:
#         </p>
#         <p style="text-align: right; font-size: 20px; color:black; font-weight:bolder; padding:0px 20px; direction:rtl;">
#  در نمودار پایین به عنوان مثال برای مقایسه میانگین تاخیر در حرکت بین دو یا چند شرکت هواپیمایی رو میتونیم داشته باشیم :
#         </p>
#     </div>

# %%
plt.figure(figsize=(10, 6))
selected_carriers = ['AA', 'DL', 'UA']  # Selected airlines
selected_df = df[df['carrier'].isin(selected_carriers)] #Filter data based on selected airlines
sns.boxplot(x='carrier', y='dep_delay', data=selected_df)  
plt.xlabel('Airlines')
plt.ylabel('departure delay')
plt.title('Comparison of the average departure delay between selected airlines')
plt.show()

# %%
#Peyman Radmanesh
